# %% [markdown]
# # Pair programming EDA

# %% [markdown]
# ## Ejercicios de exploración del conjunto de datos

# %%
import pandas as pd

# %% [markdown]
# 1_ Muestra las primeras 5 filas del conjunto de datos.

# %%
df_wd_1 = pd.read_csv('world-data-2023_part1.csv')
df_wd_1.head(5)
# Out:
#    Unnamed: 0      Country Density\n(P/Km2) Abbreviation  \
# 0           0  Afghanistan               60           AF
# 1           1      Albania              105           AL
# 2           2      Algeria               18           DZ
# 3           3      Andorra              164           AD
# 4           4       Angola               26           AO
#
#   Agricultural Land( %) Land Area(Km2) Armed Forces size  Birth Rate  \
# 0                58.10%        652,230           323,000       32.49
# 1                43.10%         28,748             9,000       11.78
# 2                17.40%      2,381,741           317,000       24.28
# 3                40.00%            468               NaN        7.20
# 4                47.50%      1,246,700           117,000       40.73
#
#    Calling Code Capital/Major City Co2-Emissions     CPI CPI Change (%)  \
# 0          93.0              Kabul         8,672   149.9          2.30%
# 1         355.0             Tirana         4,536  119.05          1.40%
# 2         213.0            Algiers       150,006  151.36          2.00%
# 3         376.0   Andorra la Vella           469     NaN            NaN
# 4         244.0             Luanda        34,693  261.73         17.10%
#
#   Currency-Code  Fertility Rate Forested Area (%) Gasoline Price
# 0           AFN            4.47             2.10%         $0.70
# 1           ALL            1.62            28.10%         $1.36
# 2           DZD            3.02             0.80%         $0.28
# 3           EUR            1.27            34.00%         $1.51
# 4           AOA            5.52            46.30%         $0.97

# %% [markdown]
# 02_Muestra las últimas 5 filas del conjunto de datos.

# %%
df_wd_1.tail(5)
# Out:
#      Unnamed: 0    Country Density\n(P/Km2) Abbreviation  \
# 190         190  Venezuela               32           VE
# 191         191    Vietnam              314           VN
# 192         192      Yemen               56           YE
# 193         193     Zambia               25           ZM
# 194         194   Zimbabwe               38           ZW
#
#     Agricultural Land( %) Land Area(Km2) Armed Forces size  Birth Rate  \
# 190                24.50%        912,050           343,000       17.88
# 191                39.30%        331,210           522,000       16.75
# 192                44.60%        527,968            40,000       30.45
# 193                32.10%        752,618            16,000       36.19
# 194                41.90%        390,757            51,000       30.68
#
#      Calling Code Capital/Major City Co2-Emissions       CPI CPI Change (%)  \
# 190          58.0            Caracas       164,175  2,740.27        254.90%
# 191          84.0              Hanoi       192,668    163.52          2.80%
# 192         967.0              Sanaa        10,609    157.58          8.10%
# 193         260.0             Lusaka         5,141    212.31          9.20%
# 194         263.0             Harare        10,983    105.51          0.90%
#
#     Currency-Code  Fertility Rate Forested Area (%) Gasoline Price
# 190           VED            2.27            52.70%         $0.00
# 191           VND            2.05            48.10%         $0.80
# 192           YER            3.79             1.00%         $0.92
# 193           ZMW            4.63            65.20%         $1.40
# 194           NaN            3.62            35.50%         $1.34

# %% [markdown]
# 03_Muestra una muestra aleatoria de 5 filas del conjunto de datos.

# %%
df_wd_1.sample(5)
# Out:
#      Unnamed: 0                         Country Density\n(P/Km2) Abbreviation  \
# 79           79                            Iran               52           IR
# 160         160                         Somalia               25           SO
# 85           85                           Japan              347           JP
# 133         133  Palestinian National Authority              847          NaN
# 120         120                           Nauru              541           NR
#
#     Agricultural Land( %) Land Area(Km2) Armed Forces size  Birth Rate  \
# 79                 28.20%      1,648,195           563,000       18.78
# 160                70.30%        637,657            20,000       41.75
# 85                 12.30%        377,944           261,000        7.40
# 133                   NaN            NaN               NaN         NaN
# 120                   NaN             21               NaN         NaN
#
#      Calling Code Capital/Major City Co2-Emissions     CPI CPI Change (%)  \
# 79           98.0             Tehran       661,710  550.93         39.90%
# 160         252.0          Mogadishu           645     NaN            NaN
# 85           81.0              Tokyo     1,135,886  105.48          0.50%
# 133           NaN                NaN           NaN     NaN            NaN
# 120         674.0     Yaren District           NaN     NaN            NaN
#
#     Currency-Code  Fertility Rate Forested Area (%) Gasoline Price
# 79            IRR            2.14             6.60%         $0.40
# 160           SOS            6.07            10.00%         $1.41
# 85            NaN            1.42            68.50%         $1.06
# 133           NaN             NaN               NaN            NaN
# 120           AUD             NaN               NaN            NaN

# %% [markdown]
# 04_Muestra el número total de filas y columnas en el conjunto de datos.

# %%
# Display the number of rows and columns
print("Number of rows: {}".format(df_wd_1.shape[0]))
print("Number of columns: {}".format(df_wd_1.shape[1]))
# Out:
# Number of rows: 195
# Number of columns: 17

# %% [markdown]
# 05_Muestra el nombre de todas las columnas en el conjunto de datos.

# %%
df_wd_1.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'Density\n(P/Km2)', 'Abbreviation',
#        'Agricultural Land( %)', 'Land Area(Km2)', 'Armed Forces size',
#        'Birth Rate', 'Calling Code', 'Capital/Major City', 'Co2-Emissions',
#        'CPI', 'CPI Change (%)', 'Currency-Code', 'Fertility Rate',
#        'Forested Area (%)', 'Gasoline Price'],
#       dtype='object')

# %% [markdown]
# 06_Muestra los valores únicos en la columna "Abbreviation".

# %%
df_wd_1['Abbreviation'].unique()
# Out:
# array(['AF', 'AL', 'DZ', 'AD', 'AO', 'AG', 'AR', 'AM', 'AU', 'AT', 'AZ',
#        'BS', 'BH', 'BD', 'BB', 'BY', 'BE', 'BZ', 'BJ', 'BT', 'BO', 'BA',
#        'BW', 'BR', 'BN', 'BG', 'BF', 'BI', 'CI', 'CV', 'KH', 'CM', 'CA',
#        'CF', 'TD', 'CL', 'CN', 'CO', 'KM', nan, 'CR', 'HR', 'CU', 'CY',
#        'CZ', 'CD', 'DK', 'DJ', 'DM', 'DO', 'EC', 'EG', 'SV', 'GQ', 'ER',
#        'EE', 'ET', 'FJ', 'FI', 'FR', 'GA', 'GM', 'GE', 'DE', 'GH', 'GR',
#        'GD', 'GT', 'GN', 'GW', 'GY', 'HT', 'HN', 'HU', 'IS', 'IN', 'ID',
#        'IR', 'IQ', 'IL', 'IT', 'JM', 'JP', 'JO', 'KZ', 'KE', 'KI', 'KW',
#        'KG', 'LA', 'LV', 'LB', 'LS', 'LR', 'LY', 'LI', 'LT', 'LU', 'MG',
#        'MW', 'MY', 'MV', 'ML', 'MT', 'MH', 'MR', 'MU', 'MX', 'FM', 'MD',
#        'MC', 'MN', 'ME', 'MA', 'MZ', 'MM', 'NR', 'NP', 'NL', 'NZ', 'NI',
#        'NE', 'NG', 'KP', 'NO', 'OM', 'PK', 'PW', 'PA', 'PG', 'PY', 'PE',
#        'PH', 'PL', 'PT', 'QA', 'RO', 'RU', 'RW', 'KN', 'LC', 'VC', 'WS',
#        'SM', 'ST', 'SA', 'SN', 'RS', 'SC', 'SL', 'SG', 'SK', 'SI', 'SB',
#        'SO', 'ZA', 'KR', 'SS', 'ES', 'LK', 'SD', 'SR', 'SE', 'CH', 'SY',
#        'TJ', 'TZ', 'TH', 'TL', 'TG', 'TO', 'TT', 'TN', 'TR', 'TM', 'TV',
#        'UG', 'UA', 'AE', 'GB', 'US', 'UY', 'UZ', 'VU', 'VE', 'VN', 'YE',
#        'ZM', 'ZW'], dtype=object)

# %% [markdown]
# 07_Cuenta cuántas veces aparece cada valor único en la columna "Abbreviation".

# %%
df_wd_1['Abbreviation'].value_counts()
# Out:
# AF    1
# PY    1
# NE    1
# NG    1
# KP    1
#      ..
# GR    1
# GD    1
# GT    1
# GN    1
# ZW    1
# Name: Abbreviation, Length: 188, dtype: int64

# %% [markdown]
# 08_Verifica si hay valores nulos en el conjunto de datos.

# %%
df_wd_1.isnull().sum()
# Out:
# Unnamed: 0                0
# Country                   0
# Density\n(P/Km2)          0
# Abbreviation              7
# Agricultural Land( %)     7
# Land Area(Km2)            1
# Armed Forces size        24
# Birth Rate                6
# Calling Code              1
# Capital/Major City        3
# Co2-Emissions             7
# CPI                      17
# CPI Change (%)           16
# Currency-Code            15
# Fertility Rate            7
# Forested Area (%)         7
# Gasoline Price           20
# dtype: int64

# %% [markdown]
# 09_Verifica si hay valores no nulos en el conjunto de datos.

# %%
df_wd_1.notnull().sum()
# Out:
# Unnamed: 0               195
# Country                  195
# Density\n(P/Km2)         195
# Abbreviation             188
# Agricultural Land( %)    188
# Land Area(Km2)           194
# Armed Forces size        171
# Birth Rate               189
# Calling Code             194
# Capital/Major City       192
# Co2-Emissions            188
# CPI                      178
# CPI Change (%)           179
# Currency-Code            180
# Fertility Rate           188
# Forested Area (%)        188
# Gasoline Price           175
# dtype: int64

# %% [markdown]
# 10_Muestra información general sobre el conjunto de datos.

# %%
df_wd_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             195 non-null    int64
#  1   Country                195 non-null    object
#  2   Density
# (P/Km2)        195 non-null    object
#  3   Abbreviation           188 non-null    object
#  4   Agricultural Land( %)  188 non-null    object
#  5   Land Area(Km2)         194 non-null    object
#  6   Armed Forces size      171 non-null    object
#  7   Birth Rate             189 non-null    float64
#  8   Calling Code           194 non-null    float64
#  9   Capital/Major City     192 non-null    object
#  10  Co2-Emissions          188 non-null    object
#  11  CPI                    178 non-null    object
#  12  CPI Change (%)         179 non-null    object
#  13  Currency-Code          180 non-null    object
#  14  Fertility Rate         188 non-null    float64
#  15  Forested Area (%)      188 non-null    object
#  16  Gasoline Price         175 non-null    object
# dtypes: float64(3), int64(1), object(13)
# memory usage: 26.0+ KB

# %% [markdown]
# 11_Elimina una columna específica (por ejemplo, "Armed Forces size").

# %%
df_wd_1.drop('Armed Forces size', axis=1)
# Out:
#      Unnamed: 0      Country Density\n(P/Km2) Abbreviation  \
# 0             0  Afghanistan               60           AF
# 1             1      Albania              105           AL
# 2             2      Algeria               18           DZ
# 3             3      Andorra              164           AD
# 4             4       Angola               26           AO
# ..          ...          ...              ...          ...
# 190         190    Venezuela               32           VE
# 191         191      Vietnam              314           VN
# 192         192        Yemen               56           YE
# 193         193       Zambia               25           ZM
# 194         194     Zimbabwe               38           ZW
#
#     Agricultural Land( %) Land Area(Km2)  Birth Rate  Calling Code  \
# 0                  58.10%        652,230       32.49          93.0
# 1                  43.10%         28,748       11.78         355.0
# 2                  17.40%      2,381,741       24.28         213.0
# 3                  40.00%            468        7.20         376.0
# 4                  47.50%      1,246,700       40.73         244.0
# ..                    ...            ...         ...           ...
# 190                24.50%        912,050       17.88          58.0
# 191                39.30%        331,210       16.75          84.0
# 192                44.60%        527,968       30.45         967.0
# 193                32.10%        752,618       36.19         260.0
# 194                41.90%        390,757       30.68         263.0
#
#     Capital/Major City Co2-Emissions       CPI CPI Change (%) Currency-Code  \
# 0                Kabul         8,672     149.9          2.30%           AFN
# 1               Tirana         4,536    119.05          1.40%           ALL
# 2              Algiers       150,006    151.36          2.00%           DZD
# 3     Andorra la Vella           469       NaN            NaN           EUR
# 4               Luanda        34,693    261.73         17.10%           AOA
# ..                 ...           ...       ...            ...           ...
# 190            Caracas       164,175  2,740.27        254.90%           VED
# 191              Hanoi       192,668    163.52          2.80%           VND
# 192              Sanaa        10,609    157.58          8.10%           YER
# 193             Lusaka         5,141    212.31          9.20%           ZMW
# 194             Harare        10,983    105.51          0.90%           NaN
#
#      Fertility Rate Forested Area (%) Gasoline Price
# 0              4.47             2.10%         $0.70
# 1              1.62            28.10%         $1.36
# 2              3.02             0.80%         $0.28
# 3              1.27            34.00%         $1.51
# 4              5.52            46.30%         $0.97
# ..              ...               ...            ...
# 190            2.27            52.70%         $0.00
# 191            2.05            48.10%         $0.80
# 192            3.79             1.00%         $0.92
# 193            4.63            65.20%         $1.40
# 194            3.62            35.50%         $1.34
#
# [195 rows x 16 columns]

# %% [markdown]
# 12_Selecciona las columnas numéricas del conjunto de datos y muestra sus estadísticas descriptivas básicas (para esto tendréis que usar el método '.describe(), su documentación la tenéis aquí).

# %%
(df_wd_1.select_dtypes(include='number')).describe
# Out:
# <bound method NDFrame.describe of      Unnamed: 0  Birth Rate  Calling Code  Fertility Rate
# 0             0       32.49          93.0            4.47
# 1             1       11.78         355.0            1.62
# 2             2       24.28         213.0            3.02
# 3             3        7.20         376.0            1.27
# 4             4       40.73         244.0            5.52
# ..          ...         ...           ...             ...
# 190         190       17.88          58.0            2.27
# 191         191       16.75          84.0            2.05
# 192         192       30.45         967.0            3.79
# 193         193       36.19         260.0            4.63
# 194         194       30.68         263.0            3.62
#
# [195 rows x 4 columns]>

# %% [markdown]
# ## Ejercicios con loc e iloc

# %% [markdown]
# 01_Selecciona todas las columnas de las filas 2 a 4 (inclusive) utilizando loc.

# %%
df_wd_1.loc[1:3, :]
# Out:
#    Unnamed: 0  Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 1           1  Albania              105           AL                43.10%
# 2           2  Algeria               18           DZ                17.40%
# 3           3  Andorra              164           AD                40.00%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 1             Tirana         4,536  119.05          1.40%           ALL
# 2            Algiers       150,006  151.36          2.00%           DZD
# 3   Andorra la Vella           469     NaN            NaN           EUR
#
#    Fertility Rate Forested Area (%) Gasoline Price
# 1            1.62            28.10%         $1.36
# 2            3.02             0.80%         $0.28
# 3            1.27            34.00%         $1.51

# %% [markdown]
# 02_Utilizando loc, filtra el conjunto de datos para mostrar solo las filas donde la densidad (columna "Birth Rate") es mayor a 30.

# %%
df_wd_1.loc[df_wd_1['Birth Rate'] > 30]
# Out:
#      Unnamed: 0                           Country Density\n(P/Km2)  \
# 0             0                       Afghanistan               60
# 4             4                            Angola               26
# 18           18                             Benin              108
# 26           26                      Burkina Faso               76
# 27           27                           Burundi              463
# 28           28                       Ivory Coast               83
# 31           31                          Cameroon               56
# 33           33          Central African Republic                8
# 34           34                              Chad               13
# 38           38                           Comoros              467
# 39           39             Republic of the Congo               16
# 45           45  Democratic Republic of the Congo               40
# 53           53                 Equatorial Guinea               50
# 54           54                           Eritrea               35
# 57           57                          Ethiopia              115
# 61           61                             Gabon                9
# 62           62                        The Gambia              239
# 69           69                            Guinea               53
# 70           70                     Guinea-Bissau               70
# 96           96                           Liberia               53
# 101         101                        Madagascar               48
# 102         102                            Malawi              203
# 105         105                              Mali               17
# 108         108                        Mauritania                5
# 117         117                        Mozambique               40
# 125         125                             Niger               19
# 126         126                           Nigeria              226
# 144         144                            Rwanda              525
# 150         150                      S�����������              228
# 152         152                           Senegal               87
# 155         155                      Sierra Leone              111
# 159         159                   Solomon Islands               25
# 160         160                           Somalia               25
# 163         163                       South Sudan               18
# 166         166                             Sudan               25
# 171         171                        Tajikistan               68
# 172         172                          Tanzania               67
# 175         175                              Togo              152
# 182         182                            Uganda              229
# 192         192                             Yemen               56
# 193         193                            Zambia               25
# 194         194                          Zimbabwe               38
#
#     Abbreviation Agricultural Land( %) Land Area(Km2) Armed Forces size  \
# 0             AF                58.10%        652,230           323,000
# 4             AO                47.50%      1,246,700           117,000
# 18            BJ                33.30%        112,622            12,000
# 26            BF                44.20%        274,200            11,000
# 27            BI                79.20%         27,830            31,000
# 28            CI                64.80%        322,463            27,000
# 31            CM                20.60%        475,440            24,000
# 33            CF                 8.20%        622,984             8,000
# 34            TD                39.70%      1,284,000            35,000
# 38            KM                71.50%          2,235               NaN
# 39           NaN                31.10%        342,000            12,000
# 45            CD                11.60%      2,344,858           134,000
# 53            GQ                10.10%         28,051             1,000
# 54            ER                75.20%        117,600           202,000
# 57            ET                36.30%      1,104,300           138,000
# 61            GA                20.00%        267,667             7,000
# 62            GM                59.80%         11,300             1,000
# 69            GN                59.00%        245,857            13,000
# 70            GW                58.00%         36,125             4,000
# 96            LR                28.00%        111,369             2,000
# 101           MG                71.20%        587,041            22,000
# 102           MW                61.40%        118,484            15,000
# 105           ML                33.80%      1,240,192            18,000
# 108           MR                38.50%      1,030,700            21,000
# 117           MZ                63.50%        799,380            11,000
# 125           NE                36.10%      1,267,000            10,000
# 126           NG                77.70%        923,768           215,000
# 144           RW                73.40%         26,338            35,000
# 150           ST                50.70%            964             1,000
# 152           SN                46.10%        196,722            19,000
# 155           SL                54.70%         71,740             9,000
# 159           SB                 3.90%         28,896               NaN
# 160           SO                70.30%        637,657            20,000
# 163           SS                   NaN        644,329           185,000
# 166           SD                28.70%      1,861,484           124,000
# 171           TJ                34.10%        144,100            17,000
# 172           TZ                44.80%        947,300            28,000
# 175           TG                70.20%         56,785            10,000
# 182           UG                71.90%        241,038            46,000
# 192           YE                44.60%        527,968            40,000
# 193           ZM                32.10%        752,618            16,000
# 194           ZW                41.90%        390,757            51,000
#
#      Birth Rate  Calling Code Capital/Major City Co2-Emissions       CPI  \
# 0         32.49          93.0              Kabul         8,672     149.9
# 4         40.73         244.0             Luanda        34,693    261.73
# 18        36.22         229.0         Porto-Novo         6,476    110.71
# 26        37.93         226.0        Ouagadougou         3,418    106.58
# 27        39.01         257.0          Bujumbura           495    182.11
# 28        35.74         225.0       Yamoussoukro         9,674    111.61
# 31        35.39         237.0            Yaound�         8,291    118.65
# 33        35.35         236.0             Bangui           297    186.86
# 34        42.17         235.0          N'Djamena         1,016     117.7
# 38        31.88         269.0    Moroni, Comoros           202    103.62
# 39        32.86         242.0        Brazzaville         3,282    124.74
# 45        41.18         243.0           Kinshasa         2,021    133.85
# 53        33.24         240.0             Malabo         5,655    124.35
# 54        30.30         291.0             Asmara           711       NaN
# 57        32.34         251.0        Addis Ababa        14,870    143.86
# 61        31.61         241.0         Libreville         5,321    122.19
# 62        38.54         220.0             Banjul           532    172.73
# 69        36.36         224.0            Conakry         2,996    262.95
# 70        35.13         245.0             Bissau           293    111.65
# 96        33.04         231.0           Monrovia         1,386    223.13
# 101       32.66         261.0       Antananarivo         3,905    184.33
# 102       34.12         265.0           Lilongwe         1,298    418.34
# 105       41.54         223.0             Bamako         3,179    108.73
# 108       33.69         222.0         Nouakchott         2,739    135.02
# 117       37.52         258.0             Maputo         7,943    182.31
# 125       46.08         227.0             Niamey         2,017    109.32
# 126       37.91         234.0              Abuja       120,369    267.51
# 144       31.70         250.0             Kigali         1,115    151.09
# 150       31.54         239.0              S����           121    185.09
# 152       34.52         221.0              Dakar        10,902    109.25
# 155       33.41         232.0           Freetown         1,093    234.16
# 159       32.44         677.0            Honiara           169    133.06
# 160       41.75         252.0          Mogadishu           645       NaN
# 163       35.01         211.0               Juba         1,727  4,583.71
# 166       32.18         249.0           Khartoum        20,000  1,344.19
# 171       30.76         992.0           Dushanbe         5,310    148.57
# 172       36.70         255.0             Dodoma        11,973    187.43
# 175       33.11         228.0               Lom�         3,000     113.3
# 182       38.14         256.0            Kampala         5,680    173.87
# 192       30.45         967.0              Sanaa        10,609    157.58
# 193       36.19         260.0             Lusaka         5,141    212.31
# 194       30.68         263.0             Harare        10,983    105.51
#
#     CPI Change (%) Currency-Code  Fertility Rate Forested Area (%)  \
# 0            2.30%           AFN            4.47             2.10%
# 4           17.10%           AOA            5.52            46.30%
# 18          -0.90%           XOF            4.84            37.80%
# 26          -3.20%           XOF            5.19            19.30%
# 27          -0.70%           BIF            5.41            10.90%
# 28          -0.90%           XOF            4.65            32.70%
# 31           2.50%           XAF            4.57            39.30%
# 33          37.10%           NaN            4.72            35.60%
# 34          -1.00%           XAF            5.75             3.80%
# 38          -4.30%           KMF            4.21            19.70%
# 39           2.20%           XAF            4.43            65.40%
# 45           2.90%           CDF            5.92            67.20%
# 53           1.20%           XAF            4.51            55.50%
# 54             NaN           ERN            4.06            14.90%
# 57          15.80%           ETB            4.25            12.50%
# 61           2.10%           XAF            3.97            90.00%
# 62           7.10%           GMD            5.22            48.40%
# 69           9.50%           GNF            4.70            25.80%
# 70           1.40%           XOF            4.48            69.80%
# 96          23.60%           NaN            4.32            43.10%
# 101          5.60%           MGA            4.08            21.40%
# 102          9.40%           MWK            4.21            33.20%
# 105         -1.70%           XOF            5.88             3.80%
# 108          2.30%           MRU            4.56             0.20%
# 117          2.80%           MZN            4.85            48.00%
# 125         -2.50%           XOF            6.91             0.90%
# 126         11.40%           NGN            5.39             7.20%
# 144          3.40%           RWF            4.04            19.70%
# 150          7.90%           STN            4.32            55.80%
# 152          1.80%           XOF            4.63            42.80%
# 155         14.80%           SLL            4.26            43.10%
# 159          1.60%           SBD            4.40            77.90%
# 160            NaN           SOS            6.07            10.00%
# 163        187.90%           SSP            4.70               NaN
# 166         51.00%           SDG            4.41             8.10%
# 171          6.00%           TJS            3.59             3.00%
# 172          3.50%           TZS            4.89            51.60%
# 175          0.70%           XOF            4.32             3.10%
# 182          2.90%           UGX            4.96             9.70%
# 192          8.10%           YER            3.79             1.00%
# 193          9.20%           ZMW            4.63            65.20%
# 194          0.90%           NaN            3.62            35.50%
#
#     Gasoline Price
# 0           $0.70
# 4           $0.97
# 18          $0.72
# 26          $0.98
# 27          $1.21
# 28          $0.93
# 31          $1.03
# 33          $1.41
# 34          $0.78
# 38             NaN
# 39          $0.97
# 45          $1.49
# 53             NaN
# 54          $2.00
# 57          $0.75
# 61          $0.92
# 62          $1.18
# 69          $0.90
# 70             NaN
# 96          $0.80
# 101         $1.11
# 102         $1.15
# 105         $1.12
# 108         $1.13
# 117         $0.65
# 125         $0.88
# 126         $0.46
# 144         $1.17
# 150            NaN
# 152         $1.14
# 155         $1.08
# 159            NaN
# 160         $1.41
# 163         $0.28
# 166         $0.95
# 171         $0.71
# 172         $0.87
# 175         $0.71
# 182         $0.94
# 192         $0.92
# 193         $1.40
# 194         $1.34

# %% [markdown]
# 03_Utilizando loc selecciona las columnas "Country" y "Capital/Major City" de las filas donde el porcentaje de tierra agrícola (columna "Fertility Rate") es superior al 3.

# %%
df_wd_1.loc[df_wd_1['Fertility Rate'] > 3, ['Country', 'Capital/Major City']]
# Out:
#                               Country Capital/Major City
# 0                         Afghanistan              Kabul
# 2                             Algeria            Algiers
# 4                              Angola             Luanda
# 18                              Benin         Porto-Novo
# 26                       Burkina Faso        Ouagadougou
# 27                            Burundi          Bujumbura
# 28                        Ivory Coast       Yamoussoukro
# 31                           Cameroon            Yaound�
# 33           Central African Republic             Bangui
# 34                               Chad          N'Djamena
# 38                            Comoros    Moroni, Comoros
# 39              Republic of the Congo        Brazzaville
# 45   Democratic Republic of the Congo           Kinshasa
# 51                              Egypt              Cairo
# 53                  Equatorial Guinea             Malabo
# 54                            Eritrea             Asmara
# 57                           Ethiopia        Addis Ababa
# 61                              Gabon         Libreville
# 62                         The Gambia             Banjul
# 65                              Ghana              Accra
# 69                             Guinea            Conakry
# 70                      Guinea-Bissau             Bissau
# 80                               Iraq            Baghdad
# 82                             Israel          Jerusalem
# 88                              Kenya            Nairobi
# 89                           Kiribati       South Tarawa
# 91                         Kyrgyzstan            Bishkek
# 95                            Lesotho             Maseru
# 96                            Liberia           Monrovia
# 101                        Madagascar       Antananarivo
# 102                            Malawi           Lilongwe
# 105                              Mali             Bamako
# 107                  Marshall Islands             Majuro
# 108                        Mauritania         Nouakchott
# 111    Federated States of Micronesia            Palikir
# 117                        Mozambique             Maputo
# 119                           Namibia           Windhoek
# 125                             Niger             Niamey
# 126                           Nigeria              Abuja
# 131                          Pakistan          Islamabad
# 135                  Papua New Guinea       Port Moresby
# 144                            Rwanda             Kigali
# 148                             Samoa               Apia
# 150                      S�����������              S����
# 152                           Senegal              Dakar
# 155                      Sierra Leone           Freetown
# 159                   Solomon Islands            Honiara
# 160                           Somalia          Mogadishu
# 163                       South Sudan               Juba
# 166                             Sudan           Khartoum
# 171                        Tajikistan           Dushanbe
# 172                          Tanzania             Dodoma
# 174                        East Timor               Dili
# 175                              Togo               Lom�
# 176                             Tonga           Nuku����
# 182                            Uganda            Kampala
# 189                           Vanuatu          Port Vila
# 192                             Yemen              Sanaa
# 193                            Zambia             Lusaka
# 194                          Zimbabwe             Harare

# %% [markdown]
# 04_Encuentra el valor de "Gasoline Price" para el país cuya abreviatura es "AL" utilizando loc.

# %%
df_wd_1.loc[df_wd_1['Abbreviation'] == 'AL', 'Gasoline Price']
# Out:
# 1    $1.36
# Name: Gasoline Price, dtype: object

# %% [markdown]
# 05_Selecciona todas las columnas para el país cuya capital es "Tirana" utilizando loc.

# %%
df_wd_1.loc[df_wd_1['Capital/Major City'] == 'Tirana']
# Out:
#    Unnamed: 0  Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 1           1  Albania              105           AL                43.10%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 1         28,748             9,000       11.78         355.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 1             Tirana         4,536  119.05          1.40%           ALL
#
#    Fertility Rate Forested Area (%) Gasoline Price
# 1            1.62            28.10%         $1.36

# %% [markdown]
# 06_Filtra el conjunto de datos para mostrar solo las filas donde el índice de CPI (columna "CPI") sea igual a 128.85.

# %%
df_wd_1['CPI'].dtypes
# Out:
# dtype('O')

# %%
# la columna tiene valores tipo objeto:
        # aunq visualmente sea un número, lo tenemos que traer como objeto
df_wd_1[df_wd_1['CPI'] == "128.85"]
# Out:
#     Unnamed: 0     Country Density\n(P/Km2) Abbreviation  \
# 40          40  Costa Rica              100           CR
#
#    Agricultural Land( %) Land Area(Km2) Armed Forces size  Birth Rate  \
# 40                34.50%         51,100            10,000       13.97
#
#     Calling Code Capital/Major City Co2-Emissions     CPI CPI Change (%)  \
# 40         506.0      San Jos������         8,023  128.85          2.10%
#
#    Currency-Code  Fertility Rate Forested Area (%) Gasoline Price
# 40           CRC            1.75            54.60%         $0.98

# %% [markdown]
# 07_Encuentra la densidad (columna "Density\n(P/Km2)") para el país cuya abreviatura es "AD" utilizando loc.

# %%
df_wd_1.loc[df_wd_1['Abbreviation'] == 'AD', 'Density\n(P/Km2)']
# Out:
# 3    164
# Name: Density\n(P/Km2), dtype: object

# %% [markdown]
# 08_Selecciona las columnas "Country" y "Co2-Emissions".

# %%
df_wd_1[['Country', 'Co2-Emissions']]
# Out:
#          Country Co2-Emissions
# 0    Afghanistan         8,672
# 1        Albania         4,536
# 2        Algeria       150,006
# 3        Andorra           469
# 4         Angola        34,693
# ..           ...           ...
# 190    Venezuela       164,175
# 191      Vietnam       192,668
# 192        Yemen        10,609
# 193       Zambia         5,141
# 194     Zimbabwe        10,983
#
# [195 rows x 2 columns]

# %% [markdown]
# 09_Filtra el conjunto de datos para mostrar solo las filas donde el índice de CPI cambió un 2% (columna "CPI Change (%)").

# %%
df_wd_1[df_wd_1['CPI Change (%)'] == '2.00%']
# Out:
#    Unnamed: 0  Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 2           2  Algeria               18           DZ                17.40%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 2      2,381,741           317,000       24.28         213.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 2            Algiers       150,006  151.36          2.00%           DZD
#
#    Fertility Rate Forested Area (%) Gasoline Price
# 2            3.02             0.80%         $0.28

# %% [markdown]
# 10_Encuentra la tasa de natalidad (columna "Birth Rate") para el país con la abreviatura "AF" utilizando loc.

# %%
df_wd_1.loc[df_wd_1['Abbreviation'] == 'AF', 'Birth Rate']
# Out:
# 0    32.49
# Name: Birth Rate, dtype: float64

# %% [markdown]
# 11_Selecciona todas las columnas de las filas 3 a 5 (excluyendo la fila 5) utilizando iloc.

# %%
df_wd_1.iloc[2:4, :]
# Out:
#    Unnamed: 0  Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 2           2  Algeria               18           DZ                17.40%
# 3           3  Andorra              164           AD                40.00%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 2            Algiers       150,006  151.36          2.00%           DZD
# 3   Andorra la Vella           469     NaN            NaN           EUR
#
#    Fertility Rate Forested Area (%) Gasoline Price
# 2            3.02             0.80%         $0.28
# 3            1.27            34.00%         $1.51

# %% [markdown]
# 12_Selecciona las columnas 1, 3 y 6 para todas las filas utilizando iloc.

# %%
df_wd_1.iloc[:, [1, 3, 6]]
# Out:
#          Country Abbreviation Armed Forces size
# 0    Afghanistan           AF           323,000
# 1        Albania           AL             9,000
# 2        Algeria           DZ           317,000
# 3        Andorra           AD               NaN
# 4         Angola           AO           117,000
# ..           ...          ...               ...
# 190    Venezuela           VE           343,000
# 191      Vietnam           VN           522,000
# 192        Yemen           YE            40,000
# 193       Zambia           ZM            16,000
# 194     Zimbabwe           ZW            51,000
#
# [195 rows x 3 columns]

# %% [markdown]
# 13_Selecciona todas las filas de las columnas 0 a 4 (excluyendo la columna 4) utilizando iloc.

# %%
df_wd_1.iloc[:, list(range(4)) + list(range(5, len(df_wd_1.columns)))]
# Out:
#      Unnamed: 0      Country Density\n(P/Km2) Abbreviation Land Area(Km2)  \
# 0             0  Afghanistan               60           AF        652,230
# 1             1      Albania              105           AL         28,748
# 2             2      Algeria               18           DZ      2,381,741
# 3             3      Andorra              164           AD            468
# 4             4       Angola               26           AO      1,246,700
# ..          ...          ...              ...          ...            ...
# 190         190    Venezuela               32           VE        912,050
# 191         191      Vietnam              314           VN        331,210
# 192         192        Yemen               56           YE        527,968
# 193         193       Zambia               25           ZM        752,618
# 194         194     Zimbabwe               38           ZW        390,757
#
#     Armed Forces size  Birth Rate  Calling Code Capital/Major City  \
# 0             323,000       32.49          93.0              Kabul
# 1               9,000       11.78         355.0             Tirana
# 2             317,000       24.28         213.0            Algiers
# 3                 NaN        7.20         376.0   Andorra la Vella
# 4             117,000       40.73         244.0             Luanda
# ..                ...         ...           ...                ...
# 190           343,000       17.88          58.0            Caracas
# 191           522,000       16.75          84.0              Hanoi
# 192            40,000       30.45         967.0              Sanaa
# 193            16,000       36.19         260.0             Lusaka
# 194            51,000       30.68         263.0             Harare
#
#     Co2-Emissions       CPI CPI Change (%) Currency-Code  Fertility Rate  \
# 0           8,672     149.9          2.30%           AFN            4.47
# 1           4,536    119.05          1.40%           ALL            1.62
# 2         150,006    151.36          2.00%           DZD            3.02
# 3             469       NaN            NaN           EUR            1.27
# 4          34,693    261.73         17.10%           AOA            5.52
# ..            ...       ...            ...           ...             ...
# 190       164,175  2,740.27        254.90%           VED            2.27
# 191       192,668    163.52          2.80%           VND            2.05
# 192        10,609    157.58          8.10%           YER            3.79
# 193         5,141    212.31          9.20%           ZMW            4.63
# 194        10,983    105.51          0.90%           NaN            3.62
#
#     Forested Area (%) Gasoline Price
# 0               2.10%         $0.70
# 1              28.10%         $1.36
# 2               0.80%         $0.28
# 3              34.00%         $1.51
# 4              46.30%         $0.97
# ..                ...            ...
# 190            52.70%         $0.00
# 191            48.10%         $0.80
# 192             1.00%         $0.92
# 193            65.20%         $1.40
# 194            35.50%         $1.34
#
# [195 rows x 16 columns]

# %% [markdown]
# 14_Encuentra el valor en la fila 2 y columna 7 utilizando iloc.

# %%
df_wd_1.iloc[1, 7]
# Out:
# 11.78

# %% [markdown]
# 15_Selecciona todas las filas para las columnas 0, 2, y 5 utilizando iloc.

# %%
df_wd_1.iloc[:, [0, 2, 5]]
# Out:
#      Unnamed: 0 Density\n(P/Km2) Land Area(Km2)
# 0             0               60        652,230
# 1             1              105         28,748
# 2             2               18      2,381,741
# 3             3              164            468
# 4             4               26      1,246,700
# ..          ...              ...            ...
# 190         190               32        912,050
# 191         191              314        331,210
# 192         192               56        527,968
# 193         193               25        752,618
# 194         194               38        390,757
#
# [195 rows x 3 columns]

# %% [markdown]
# 16_Selecciona las filas 0, 2 y 4 para todas las columnas utilizando iloc.

# %%
df_wd_1.iloc[[0, 2, 4], :]
# Out:
#    Unnamed: 0      Country Density\n(P/Km2) Abbreviation  \
# 0           0  Afghanistan               60           AF
# 2           2      Algeria               18           DZ
# 4           4       Angola               26           AO
#
#   Agricultural Land( %) Land Area(Km2) Armed Forces size  Birth Rate  \
# 0                58.10%        652,230           323,000       32.49
# 2                17.40%      2,381,741           317,000       24.28
# 4                47.50%      1,246,700           117,000       40.73
#
#    Calling Code Capital/Major City Co2-Emissions     CPI CPI Change (%)  \
# 0          93.0              Kabul         8,672   149.9          2.30%
# 2         213.0            Algiers       150,006  151.36          2.00%
# 4         244.0             Luanda        34,693  261.73         17.10%
#
#   Currency-Code  Fertility Rate Forested Area (%) Gasoline Price
# 0           AFN            4.47             2.10%         $0.70
# 2           DZD            3.02             0.80%         $0.28
# 4           AOA            5.52            46.30%         $0.97

# %% [markdown]
# 17_Encuentra el valor en la última fila y la última columna utilizando iloc.

# %%
df_wd_1.iloc[-1, -1]
# Out:
# '$1.34 '

# %% [markdown]
# 18_Selecciona las filas 1 a 3 (inclusive) para todas las columnas utilizando iloc.

# %%
df_wd_1.iloc[1:4, :]
# Out:
#    Unnamed: 0  Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 1           1  Albania              105           AL                43.10%
# 2           2  Algeria               18           DZ                17.40%
# 3           3  Andorra              164           AD                40.00%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 1             Tirana         4,536  119.05          1.40%           ALL
# 2            Algiers       150,006  151.36          2.00%           DZD
# 3   Andorra la Vella           469     NaN            NaN           EUR
#
#    Fertility Rate Forested Area (%) Gasoline Price
# 1            1.62            28.10%         $1.36
# 2            3.02             0.80%         $0.28
# 3            1.27            34.00%         $1.51

# %% [markdown]
# 19_Selecciona todas las filas para las columnas 1, 4 y 6 utilizando iloc.

# %%
df_wd_1.iloc[:, [1, 4, 6]]
# Out:
#          Country Agricultural Land( %) Armed Forces size
# 0    Afghanistan                58.10%           323,000
# 1        Albania                43.10%             9,000
# 2        Algeria                17.40%           317,000
# 3        Andorra                40.00%               NaN
# 4         Angola                47.50%           117,000
# ..           ...                   ...               ...
# 190    Venezuela                24.50%           343,000
# 191      Vietnam                39.30%           522,000
# 192        Yemen                44.60%            40,000
# 193       Zambia                32.10%            16,000
# 194     Zimbabwe                41.90%            51,000
#
# [195 rows x 3 columns]

# %% [markdown]
# 20_Encuentra el valor en la fila 4 y columna 2 utilizando iloc.

# %%
df_wd_1.iloc[4, 2]
# Out:
# '26'
